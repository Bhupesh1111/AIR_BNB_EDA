# %% [markdown]
# ![Airbnb_Logo_Bélo.svg](data:image/svg+xml;base64,...)

# %% [markdown]
# # **AirBnb Booking Analysis**    -

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ##### **Project Type**    - EDA on Airbnb
# ##### **Contribution**    -Team
# ##### **Team Member 1 -** Sudip Paul
# ##### **Team Member 2 -** Pooja Bramhvanshi
# ##### **Team Member 3 -** Sharik Nawaz
# ##### **Team Member 4 -** Bhupesh Rajput
# ##### **Team Member 5 -** Siddharth

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# #Since 2008, guests and hosts have used Airbnb to expand on traveling possibilities and present a more unique, personalized way of experiencing the world. Today, Airbnb became one of a kind service that is used and recognized by the whole world. Data analysis on millions of listings provided through Airbnb is a crucial factor for the company. These millions of listings generate a lot of data - data that can be analyzed and used for security, business decisions, understanding of customers' and providers' (hosts) behavior and performance on the platform, guiding marketing initiatives, implementation of innovative additional services and much more.
# #This dataset has around 49,000 observations in it with 16 columns and it is a mix between categorical and numeric values.
# #Through EDA, Airbnb can understand pricing trends, identify popular neighborhoods, optimize search ranking, improve the guest experience, and identify opportunities for growth.
#
# #Some of the specific findings that can be derived from EDA of Airbnb data include identifying the most popular neighborhoods for guests, understanding the factors that influence pricing, such as seasonality and demand, identifying areas where hosts need to improve, and providing targeted training and support to hosts to improve the overall guest experience.
#
# #Overall, EDA of Airbnb data is an important tool for making data-driven business decisions and improving the overall quality of the Airbnb platform. By leveraging the insights derived from EDA, Airbnb can improve the guest experience, attract more hosts and guests to its platform, and grow its business

# %% [markdown]
# # **GitHub Link -**
# https://github.com/Bhupesh1111/AIR_BNB_EDA.git

# %% [markdown]
# https://github.com/Sharik2610/Air-Bnb-Booking-Analysis-EDA

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# #The business objective of EDA (Exploratory Data Analysis) for Airbnb data could be to gain insights into the behavior of hosts and guests, and to identify patterns and trends that can help in making business decisions. Here are some specific business objectives that can be achieved through EDA of Airbnb data.Understanding pricing trends: By analyzing pricing trends across different neighborhoods, Airbnb can gain insights into the factors that influence pricing, such as demand, and competition. This can help Airbnb set optimal pricing.Identifying popular neighborhoods: By analyzing booking data, Airbnb can identify the most popular neighborhoods for guests.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
from datetime import datetime
import missingno as msno # searched from google
import matplotlib.pyplot as plt
# %matplotlib inline
from datetime import datetime
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/MyDrive/Alma Better/Capstone/Airbnb NYC 2019.csv'
df=pd.read_csv(file_path)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %%
# Dataset last five row look
df.tail()
# Out:
#              id                                               name   host_id  \
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 48890  -73.94995     Private room     70               2                  0
# 48891  -73.93317     Private room     40               4                  0
# 48892  -73.94867  Entire home/apt    115              10                  0
# 48893  -73.99112      Shared room     55               1                  0
# 48894  -73.98933     Private room     90               7                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 48890         NaN                NaN                               2
# 48891         NaN                NaN                               2
# 48892         NaN                NaN                               1
# 48893         NaN                NaN                               6
# 48894         NaN                NaN                               1
#
#        availability_365
# 48890                 9
# 48891                36
# 48892                27
# 48893                 2
# 48894                23

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print(f'we have total {df.shape[0]} rows and {df.shape[1]} columns.')
# Out:
# we have total 48895 rows and 16 columns.

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
#  12  last_review                     38843 non-null  object
#  13  reviews_per_month               38843 non-null  float64
#  14  calculated_host_listings_count  48895 non-null  int64
#  15  availability_365                48895 non-null  int64
# dtypes: float64(3), int64(7), object(6)
# memory usage: 6.0+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
NO_of_duplicate_rows=df[df.duplicated()].shape[0]
print(f'we hve total no {NO_of_duplicate_rows} duplicate rows.')
# Out:
# we hve total no 0 duplicate rows.

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isna().sum().sort_values(ascending=False)[:10].reset_index().rename(columns = {'index':'columns',0:'null values'})
# Out:
#                columns  null values
# 0          last_review        10052
# 1    reviews_per_month        10052
# 2            host_name           21
# 3                 name           16
# 4                   id            0
# 5              host_id            0
# 6  neighbourhood_group            0
# 7        neighbourhood            0
# 8             latitude            0
# 9            longitude            0

# %%
# Visualizing the missing value

null_counts = df.isnull().sum()

# Plot a bar chart of null values
plt.bar(null_counts.index, null_counts.values)

plt.xticks(rotation=90)
plt.ylabel("Number of Null Values")
plt.show()

# %%
sns.heatmap(df.isnull(), cmap="viridis")

plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# min          1.000000           0.000000           0.010000
# 25%          1.000000           1.000000           0.190000
# 50%          3.000000           5.000000           0.720000
# 75%          5.000000          24.000000           2.020000
# max       1250.000000         629.000000          58.500000
#
#        calculated_host_listings_count  availability_365
# count                    48895.000000      48895.000000
# mean                         7.143982        112.781327
# std                         32.952519        131.622289
# min                          1.000000          0.000000
# 25%                          1.000000          0.000000
# 50%                          1.000000         45.000000
# 75%                          2.000000        227.000000
# max                        327.000000        365.000000

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here

# %% [markdown]
# ### Checking unique values for each varaible .

# %%
# Check Unique Values for each variable.
def unique_values(dF):
    unique_vals = []
    for col in dF.columns:
        unique_vals.append(dF[col].unique())
        
    return unique_vals

# %%
unique_values(df)

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# making acopy of dataframe.
airbnb = df.copy()

# %%
# filling na values 
airbnb.fillna({'reviews_per_month':0},inplace=True)
airbnb.fillna({'host_name':'Not Mentioned'}, inplace = True)

# %%
#dropping columns that are not significant for our future data exploration and predictions
airbnb.drop(['id','last_review','name'],axis=1,inplace=True)

# %%
# Lets add a new column named Price range

def get_price_range(pr):
  if pr>= 0 and pr<200:
    price_range = "0-200"
  elif pr>= 200 and pr<400:
    price_range = "200-400"
  elif pr>= 400 and pr<600:
    price_range = "400-600"
  elif pr>= 600 and pr<800:
    price_range = "600-800"
  elif pr>= 800 and pr<1000:
    price_range = "800-1000"
  else:
    price_range = ">1000"
  return price_range

# %%
airbnb['price_range'] = airbnb.apply(lambda x: get_price_range(x['price']), axis= 1)

# %%
#check the dataset now
airbnb

# %%
airbnb.describe()

# %%
#checking our all new data frame info
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   host_id                         48895 non-null  int64
#  1   host_name                       48895 non-null  object
#  2   neighbourhood_group             48895 non-null  object
#  3   neighbourhood                   48895 non-null  object
#  4   latitude                        48895 non-null  float64
#  5   longitude                       48895 non-null  float64
#  6   room_type                       48895 non-null  object
#  7   price                           48895 non-null  int64
#  8   minimum_nights                  48895 non-null  int64
#  9   number_of_reviews               48895 non-null  int64
#  10  reviews_per_month               48895 non-null  float64
#  11  calculated_host_listings_count  48895 non-null  int64
#  12  availability_365                48895 non-null  int64
#  13  price_range                     48895 non-null  object
# dtypes: float64(3), int64(6), object(5)
# memory usage: 5.2+ MB

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart-1: Plot of distribution of types of rooms booked.

plt.figure(figsize=(9,6))
plt.title('Type of Rooms Booked', {'fontsize': 18, 'fontweight': 20})

sns.countplot(x='room_type',data=airbnb)

plt.xlabel("Room Type", {'fontsize': 12, 'fontweight': 15})
plt.ylabel("No of Bookings", {'fontsize': 12, 'fontweight': 15})
# Out:
# Text(0, 0.5, 'No of Bookings')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2: Let us  take a look at total property according to neighbourhood group.

plt.figure(figsize=(12,6))
plt.title('Neighbourhoodwise Total Bookings', {'fontsize': 18, 'fontweight': 20})

sns.countplot(x='neighbourhood_group',data=airbnb)

plt.ylabel("Total Bookings", {'fontsize': 12, 'fontweight': 15})
plt.xlabel("Neighbourhood Group", {'fontsize': 12, 'fontweight': 15})
# Out:
# Text(0.5, 0, 'Neighbourhood Group')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3: Neighbourhoodwise different property Booked
plt.figure(figsize=(10,6))

plt.title('Neighbourhoodwise Different Property Booked',{'fontsize': 18, 'fontweight': 20})

sns.countplot(x='neighbourhood_group',hue= 'room_type', data=airbnb)

plt.ylabel("Total Bookings", {'fontsize': 12, 'fontweight': 15})
plt.xlabel('Neighbourhood Group', {'fontsize': 12, 'fontweight': 15})
# Out:
# Text(0.5, 0, 'Neighbourhood Group')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# answer here

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer here.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# answer here.

# %% [markdown]
# *italicized text*#### Chart - 4

# %%
# Chart - 4: Plot between Map of Property Type Distribution vs Map of Price Distribution

# Create a figure with two subplots
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(20, 6))

# Plot first subplot
sns.scatterplot(ax=axs[0], x='longitude', y='latitude', hue='neighbourhood_group', data=airbnb)

axs[0].set_title("Map of Room Type Distribution", {'fontsize': 12, 'fontweight': 15})

# Set label
axs[0].set_xlabel('Longitude', {'fontsize': 10, 'fontweight': 12})
axs[0].set_ylabel('Latitude', {'fontsize': 10, 'fontweight': 12})

# Filter data
#airbnb_filtered = airbnb[airbnb.price < 500]

# Plot second subplot
sns.scatterplot(ax=axs[1], data=airbnb[airbnb.price<500], x="longitude", y="latitude", hue="price", palette="plasma")
axs[1].legend(title="Price", bbox_to_anchor=(1.05, 1), loc=2)
axs[1].set_title("Map of Price Distribution", {'fontsize': 12, 'fontweight': 15})

# Set title
axs[0].set_xlabel('Longitude', {'fontsize': 10, 'fontweight': 12})
axs[0].set_ylabel('Latitude', {'fontsize': 10, 'fontweight': 12})
# Display the figure
plt.show()

# %% [markdown]
# answer

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5: Total Properties Booked in Different Price Range.
plt.figure(figsize=(10,8))

plt.title('Price-rangewise Different Property Booked',{'fontsize': 18, 'fontweight': 20})

sns.countplot(x='price_range', hue= 'room_type', data=airbnb)

plt.ylabel("Total Bookings", {'fontsize': 12, 'fontweight': 15})
plt.xlabel('Price Range', {'fontsize': 12, 'fontweight': 15})
# Out:
# Text(0.5, 0, 'Price Range')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 6

# %%
#Chart - 6: Neighbourhood Group-wise Distribution of Property in Different Price Range.

plt.figure(figsize=(10,8))

plt.title('Neighbourhood Group-wise Property Booked in Different Price Range',{'fontsize': 18, 'fontweight': 20})
sns.countplot(x='neighbourhood_group', hue= 'price_range', data=airbnb)

plt.ylabel("Total Bookings", {'fontsize': 12, 'fontweight': 15})
plt.xlabel('neighbourhood_group', {'fontsize': 12, 'fontweight': 15})
# Out:
# Text(0.5, 0, 'neighbourhood_group')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 Room Tyoe-wise Average Price of Rooms Booked in Each Neighbourhood

airbnb.groupby(['neighbourhood_group','room_type'])['price'].mean().unstack().plot(kind = 'bar', figsize= (10,6))

plt.title('Average price of Room Booked in Each Neighbourhood Group', {'fontsize': 18, 'fontweight': 20})

plt.xlabel('Neighbourhood Group', {'fontsize': 12, 'fontweight': 15})
plt.ylabel('Price', {'fontsize': 12, 'fontweight': 15})
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8: Pricewise Room Availability Plot of Different Properties
plt.figure(figsize=(12,10))
plt.title('Price vs Availability of Different Properties', {'fontsize': 18, 'fontweight': 20})
plt.xlabel('Price', {'fontsize': 12, 'fontweight': 15})
plt.ylabel('Availability', {'fontsize': 12, 'fontweight': 15})

sns.boxplot(x='price_range',y='availability_365', hue='room_type',palette='bright',data=airbnb)
plt.legend(title="room_type", bbox_to_anchor=(1.05, 1), loc=2)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9: visualization code
# Let's see who has the most listings and in which neighbourhood.
top_hosts = airbnb.groupby(['host_name','neighbourhood_group'])['calculated_host_listings_count'].max().reset_index().sort_values('calculated_host_listings_count',ascending=False).head(10)

top_hosts.rename(columns={'calculated_host_listings_count':'counts'},inplace=True)

top_hosts


plt.figure(figsize=(12,6))

plt.title('top 10 hosts')

sns.barplot(x='host_name',y='counts',hue='neighbourhood_group',palette='viridis',data=top_hosts)
# Out:
# <Axes: title={'center': 'top 10 hosts'}, xlabel='host_name', ylabel='counts'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10: visualization code
airbnb2 = airbnb.groupby(['neighbourhood_group','neighbourhood','room_type'])['number_of_reviews'].max().reset_index().sort_values(by = 'number_of_reviews', ascending = False).head(5)
airbnb2


# Set up the figure and axes
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the bar chart
sns.barplot(data=airbnb2, x='number_of_reviews', y='neighbourhood', hue='room_type')

# Add labels and title
ax.set_xlabel('Number of Reviews')
ax.set_ylabel('Neighborhood')
ax.set_title('Top Neighborhoods with Highest Number of checks by Room Type and Neighborhood Group')
ax.legend(loc='best')

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

corr_airbnb = airbnb[['price','minimum_nights',"neighbourhood_group",'calculated_host_listings_count','availability_365']]

sns.heatmap(corr_airbnb.corr(), cmap='RdGy',annot=True)
plt.show()
# Out:
# <ipython-input-37-db2fdb603567>:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(corr_airbnb.corr(), cmap='RdGy',annot=True)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

sns.pairplot(corr_airbnb, hue = "neighbourhood_group")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
